# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dat = pd.read_csv("iris.csv")
dat
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
dat.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
dat.hist("sepal.length", bins=30)
plt.title("Histogram")
plt.xlabel("Width")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %%
plt.figure(figsize=(6, 10))

dat.hist("sepal.length", bins = 20)
plt.title("Wahthef")
plt.xlabel("xxxxx")
plt.ylabel("yyyyyy")
# Out:
# Text(0, 0.5, 'yyyyyy')

# %%
# Set figure size 
plt.figure(figsize=(10,8)) # width 10 inch, height 8 inch

# Histogram of Sepal Length
plt.subplot(2, 2, 1) # 1st subplot position in a (2,2) grid
plt.hist(dat["sepal.length"],bins=30, color='lightblue')
plt.title('Subplot 1')

# Histogram of Sepal Width
plt.subplot(2, 2, 2) # 2nd subplot position in a (2,2) grid
plt.hist(dat["sepal.width"],bins=30, color='lightblue')
plt.title('Subplot 2')

# Histogram of Petal Length
plt.subplot(2, 2, 3)
plt.hist(dat["petal.length"],bins=30, color='lightblue')
plt.title('Subplot 3')

# Histogram of Petal Width
plt.subplot(2, 2, 4)
plt.hist(dat["petal.width"],bins=30, color='lightblue')
plt.title('Subplot 4')

plt.tight_layout()
plt.show()

# %%
freq = dat["variety"].value_counts()
print(freq)

plt.bar(freq.index, freq.values)
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64
# <BarContainer object of 3 artists>

# %%
dat["sepal.length"].plot(kind="hist", bins=30)
plt.show()

# %%
a = "Hello! I'm a 25 years old!"
print(dir(a))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
